# %% [markdown]
# # 第 12 章 结果汇总与分析报告
#
# ## 学习目标
#
# 整理可复用的分析对象，并形成有证据支持的综合报告。
#
# ## 为什么做与怎样做
#
# 保存完整 AnnData、细胞注释表与样本组成表；按当前有效运行整理目的、方法、结果和解释，以及完整附件索引。
#
# 前置章节：11。运行前请完成项目环境准备。

# %%
from __future__ import annotations
from pathlib import Path
import os
import sys
ROOT = Path(os.environ.get("SC_COURSE_ROOT", Path.cwd())).resolve()
while not (ROOT / "config/course.json").is_file() and ROOT != ROOT.parent:
    ROOT = ROOT.parent
if not (ROOT / "config/course.json").is_file():
    raise RuntimeError("请从课程目录或其 notebooks/exercises 目录运行。")
os.environ["CELLTYPIST_FOLDER"] = str(ROOT / ".runtime/celltypist")
os.environ["MPLCONFIGDIR"] = str(ROOT / ".runtime/matplotlib")
sys.path.insert(0, str(ROOT / "tools"))
from course_runtime import start_chapter, marker_sets, scaled_view
import anndata as ad
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import rc_context
from scipy.sparse import csr_matrix
from scipy.stats import median_abs_deviation
ctx = start_chapter("12")
adata = ctx.load_input()
# Out:
# 第 12 章：结果汇总与分析报告
# 结果目录：results/12_summary/20260915T080103_6b30ff
# 读取检查点：results/11_celltypist/20260915T075936_a73aa2/checkpoint.h5ad
# 17,041 个细胞 × 23,427 个基因

# %% [markdown]
# ## 12.1 保存数据

# %%
# # 功能说明：保存最终的 AnnData 对象。
# # 运行目的：将包含所有分析结果（QC、聚类、手动注释、自动注释、差异基因等）的数据保存到磁盘，以便后续使用。
# # 变量/函数/参数解析：
# # - adata.write(...)：
# #   - 保存为 `.h5ad` 格式（HDF5 AnnData）。
# #   - 这是 Scanpy 的标准存储格式，读写速度快，支持压缩。

adata.write_h5ad(ctx.directory / "annotation_adata_out.h5ad", compression="gzip")

# %%
print(adata.X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 26539065 stored elements and shape (17041, 23427)>
#   Coords	Values
#   (0, 27)	1.1075377464294434
#   (0, 43)	0.5161904096603394
#   (0, 44)	0.5161904096603394
#   (0, 46)	0.5161904096603394
#   (0, 54)	0.5161904096603394
#   (0, 55)	0.5161904096603394
#   (0, 68)	0.5161904096603394
#   (0, 83)	1.1075377464294434
#   (0, 107)	0.5161904096603394
#   (0, 118)	2.3474483489990234
#   (0, 129)	0.5161904096603394
#   (0, 132)	0.5161904096603394
#   (0, 147)	1.1075377464294434
#   (0, 155)	1.6201388835906982
#   (0, 170)	0.5161904096603394
#   (0, 171)	0.5161904096603394
#   (0, 173)	0.5161904096603394
#   (0, 221)	0.5161904096603394
#   (0, 234)	0.5161904096603394
#   (0, 239)	0.5161904096603394
#   (0, 247)	0.5161904096603394
#   (0, 248)	0.5161904096603394
#   (0, 264)	0.5161904096603394
#   (0, 280)	0.5161904096603394
#   (0, 304)	0.5161904096603394
#   :	:
#   (17040, 23325)	0.5853821039199829
#   (17040, 23326)	0.5853821039199829
#   (17040, 23332)	0.5853821039199829
#   (17040, 23333)	0.5853821039199829
#   (17040, 23337)	0.5853821039199829
#   (17040, 23338)	4.193367958068848
#   (17040, 23341)	0.5853821039199829
#   (17040, 23358)	0.5853821039199829
#   (17040, 23360)	0.5853821039199829
#   (17040, 23362)	0.5853821039199829
#   (17040, 23376)	1.7533758878707886
#   (17040, 23386)	0.5853821039199829
#   (17040, 23402)	3.3340961933135986
#   (17040, 23403)	2.428671360015869
#   (17040, 23404)	3.4912538528442383
#   (17040, 23405)	3.918640613555908
#   (17040, 23406)	0.5853821039199829
#   (17040, 23407)	4.193367958068848
#   (17040, 23408)	3.918640613555908
#   (17040, 23409)	3.7651662826538086
#   (17040, 23410)	0.9521805047988892
#   (17040, 23411)	3.000533103942871
#   (17040, 23412)	1.7533758878707886
#   (17040, 23413)	0.5853821039199829
#   (17040, 23414)	3.668485403060913

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 17041 × 23427
#     obs: 'samples', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'log1p_total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'log1p_total_counts_hb', 'pct_counts_hb', 'n_genes', 'doublet_score', 'predicted_doublet', 'leiden_res_0_02', 'leiden_res_0_50', 'leiden_res_1_00', 'leiden_res_2_00', 'cell_type_res_0.02_lvl1', 'cell_type_res_0.50_lvl1', 'cell_type_res_0.50_lvl2', 'leiden_sub', 'celltypist_cell_label_coarse', 'celltypist_conf_score_coarse', 'celltypist_predicted_label_coarse', 'celltypist_cell_label_fine', 'celltypist_conf_score_fine', 'celltypist_predicted_label_fine'
#     var: 'mt', 'ribo', 'hb', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'B_vs_T', 'X_pca_bbknn', 'X_pca_harmony', 'cell_type_res_0.02_lvl1_colors', 'cell_type_res_0.02_lvl1_rank_genes_groups', 'cell_type_res_0.50_lvl1_colors', 'cell_type_res_0.50_lvl2_colors', 'celltypist_cell_label_coarse_colors', 'celltypist_cell_label_fine_colors', 'course_markers', 'course_neighbors_key', 'dendrogram_cell_type_res_0.50_lvl2', 'dendrogram_celltypist_cell_label_fine', 'dendrogram_leiden_res_0_02', 'dendrogram_leiden_res_0_50', 'hvg', 'leiden_res_0_02', 'leiden_res_0_02_colors', 'leiden_res_0_50', 'leiden_res_0_50_colors', 'leiden_res_0_50_rank_genes_groups', 'leiden_res_1_00', 'leiden_res_1_00_colors', 'leiden_res_2_00', 'leiden_res_2_00_colors', 'leiden_sub', 'leiden_sub_colors', 'log1p', 'neighbors', 'pca', 'predicted_doublet_colors', 'samples_colors', 'scrublet', 'tsne', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_tsne', 'X_umap', 'X_umap_bbknn', 'X_umap_harmony', 'X_umap_uncorrected'
#     varm: 'PCs'
#     layers: 'counts', 'log1p'
#     obsp: 'X_pca_bbknn_connectivities', 'X_pca_bbknn_distances', 'X_pca_harmony_connectivities', 'X_pca_harmony_distances', 'connectivities', 'distances'

# %% [markdown]
# ## 保存本章结果
#
# 保存表格、参数摘要和可供后续章节读取的数据。

# %%
ctx.table("final_cell_metadata", adata.obs)
ctx.table("sample_celltype_counts", pd.crosstab(adata.obs["samples"], adata.obs["celltypist_cell_label_fine"]))
ctx.finish(adata, {"final_data": str((ctx.directory / "annotation_adata_out.h5ad").relative_to(ROOT)), "available_layers": list(adata.layers)}, save=False)
# Out:
# 本章计算完成。请阅读本次图表和表格，再更新本章解读。

# %% [markdown]
# ## 结果阅读与思考
#
# 请打开本次结果目录中的 summary.json、tables 和 figures。将目的、方法、结果和解释写入本章报告源稿，再更新 Word。
#
# 思考题：怎样让他人从报告追溯到具体图表与运行参数？
#
# 运行与报告操作见课程根目录的 99_运行与AI协作指南.md。
